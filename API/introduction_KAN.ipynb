# %% [markdown]
# # Знакомство с KAN

# %% [markdown]
# ### Теорема Калмогорова-Арнольда о представлении функции

# %% [markdown]
# Теорема Колмогорова-Арнольда о представлении сложной функции утверждает, что если $f$ - многомерная непрерывная функция ограниченная на некоторой области, то она может быть записана как конечная композиция непрерывных одномерных функций и бинарной операции сложения. Т.е. для гладкой функции $f: [0, 1]^n \to \mathbb{R}$,
#
# $$f(x) = f(x_1, x_2, ..., x_n) = \sum_{q=1}^{2n+1}\Phi_q(\sum_{p=1}^{n}\phi_{q, p}(x_p))$$
#
# где $\phi_{q,p}:[0,1]\to\mathbb{R}$ и $\Phi_q:\mathbb{R}\to\mathbb{R}$.

# %% [markdown]
# ### Начало работы с KAN

# %% [markdown]
# Инициализация KAN

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from kan import *
#       3 device = torch.set_default_device('cuda' if torch.cuda.is_available() else 'cpu')
#       4 print(device)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kan\__init__.py:1
# ----> 1 from .MultKAN import *
#       2 from .utils import *
#       3 #torch.use_deterministic_algorithms(True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kan\MultKAN.py:4
#       2 import torch.nn as nn
#       3 import numpy as np
# ----> 4 from .KANLayer import KANLayer
#       5 #from .Symbolic_MultKANLayer import *
#       6 from .Symbolic_KANLayer import Symbolic_KANLayer
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kan\KANLayer.py:5
#       3 import numpy as np
#       4 from .spline import *
# ----> 5 from .utils import sparse_mask
# ...
